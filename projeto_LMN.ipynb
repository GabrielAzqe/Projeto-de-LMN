# %%
# ==========================================
# 1. INSTALAÇÃO (Colab)
# ==========================================
# !pip install -U -q google-search-results langchain-google-genai langchain langchain-community

# %%
# ==========================================
# 2. CONFIGURAÇÃO E IMPORTS
# ==========================================
import os
import getpass
import json
from langchain_google_genai import ChatGoogleGenerativeAI
from serpapi import GoogleSearch
from datetime import datetime, timedelta

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Cole sua Google AI Key: ")

if "SERPAPI_API_KEY" not in os.environ:
    os.environ["SERPAPI_API_KEY"] = getpass.getpass("Cole sua SerpAPI Key: ")

SERPAPI_KEY = os.environ["SERPAPI_API_KEY"]

# ==========================================
# PRETTY PRINT – saída estruturada da API
# ==========================================
def print_estruturado(titulo, dados):
    print(f"\n🟦 {titulo}\n")
    try:
        print(json.dumps(dados, indent=4, ensure_ascii=False))
    except:
        print(dados)


# ==========================================
# 3. GERAR DATAS + INTERESSES VIA LLM
# ==========================================
def gerar_dados_viagem(origem, destino):
    llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

    prompt = f"""
    Escolha datas ideais para uma viagem de {origem} até {destino}.
    Regras:
    - viagem deve ter entre 5 e 12 dias.
    - escolha um mês em alta ou média temporada.
    - interesses devem ser variados (cultura, gastronomia, natureza etc.)

    Responda no formato:
    IDA: AAAA-MM-DD
    VOLTA: AAAA-MM-DD
    INTERESSES: lista separada por vírgula
    """

    resposta = llm.invoke(prompt).content
    linhas = resposta.split("\n")

    data_ida = linhas[0].split(":")[1].strip()
    data_volta = linhas[1].split(":")[1].strip()
    interesses = linhas[2].split(":")[1].strip()

    return data_ida, data_volta, interesses


# ==========================================
# 4. TRADUZIR CIDADE -> IATA
# ==========================================
def descobrir_aeroporto(cidade):
    print(f"🤔 Identificando aeroporto principal de: {cidade}...")

    llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

    prompt = f"""
    Qual é o código IATA (3 letras) do principal aeroporto internacional de: {cidade}?
    Responda apenas a sigla.
    """

    codigo = llm.invoke(prompt).content.strip()
    print(f"   ✅ Código encontrado: {codigo}")
    return codigo


# ==========================================
# 5. SERPAPI — BUSCA DE VOOS
# ==========================================
def buscar_voos_reais(origem, destino_iata, data_ida, data_volta):
    print(f"✈️  Buscando voos ({origem} -> {destino_iata})...")

    try:
        params = {
            "engine": "google_flights",
            "departure_id": origem,
            "arrival_id": destino_iata,
            "outbound_date": data_ida,
            "return_date": data_volta,
            "currency": "BRL",
            "hl": "pt",
            "api_key": SERPAPI_KEY
        }

        results = GoogleSearch(params).get_dict()
        print_estruturado("RESULTADO SERPAPI (VOOS)", results)

        voos = results.get("best_flights", []) or results.get("other_flights", [])
        if not voos:
            return "Nenhum voo encontrado."

        lista = []
        for v in voos[:3]:
            preco = v.get("price", "N/A")
            duracao = v["flights"][0].get("duration", "N/A")
            cia = v["flights"][0].get("airline", "Companhia")
            lista.append(f"- {cia}: R$ {preco} ({duracao} min)")

        return "\n".join(lista)

    except Exception as e:
        return f"Erro voos: {e}"


# ==========================================
# 6. SERPAPI — HOTÉIS
# ==========================================
def buscar_hoteis_reais(destino, checkin, checkout):
    print(f"🏨  Buscando hotéis em {destino}...")

    try:
        params = {
            "engine": "google_hotels",
            "q": f"hotéis em {destino}",
            "check_in_date": checkin,
            "check_out_date": checkout,
            "currency": "BRL",
            "hl": "pt",
            "api_key": SERPAPI_KEY
        }

        results = GoogleSearch(params).get_dict()
        print_estruturado("RESULTADO SERPAPI (HOTÉIS)", results)

        props = results.get("properties", [])[:3]
        if not props:
            return "Nenhum hotel encontrado."

        lista = []
        for h in props:
            nome = h.get("name", "Hotel")
            preco = h.get("rate_per_night", {}).get("lowest", "N/A")
            nota = h.get("overall_rating", "S/N")
            lista.append(f"- {nome}: {preco} (Nota: {nota})")

        return "\n".join(lista)

    except Exception as e:
        return f"Erro hotéis: {e}"


# ==========================================
# 7. SERPAPI — ATRAÇÕES
# ==========================================
def pesquisar_atracoes(destino, interesses):
    print(f"🔍  Pesquisando atrações em {destino}...")

    try:
        params = {
            "engine": "google",
            "q": f"melhores atrações {destino} {interesses}",
            "api_key": SERPAPI_KEY,
            "hl": "pt",
            "gl": "br"
        }

        results = GoogleSearch(params).get_dict()
        print_estruturado("RESULTADO SERPAPI (ATRAÇÕES)", results)

        org = results.get("organic_results", [])
        if not org:
            return "Nenhuma atração encontrada."

        return "\n".join(
            f"- {i.get('title')}: {i.get('snippet', '')}"
            for i in org[:4]
        )

    except:
        return "Erro atrações."


# ==========================================
# 8. SERPAPI — CÂMBIO
# ==========================================
def buscar_cambio(pais):
    print(f"💱 Buscando câmbio do país: {pais} ...")

    try:
        params = {
            "engine": "google",
            "q": f"cotação moeda {pais} hoje",
            "api_key": SERPAPI_KEY,
            "hl": "pt",
            "gl": "br"
        }

        results = GoogleSearch(params).get_dict()
        print_estruturado("RESULTADO SERPAPI (CÂMBIO)", results)

        org = results.get("organic_results", [])
        if not org:
            return "Câmbio não encontrado."

        return org[0].get("snippet", "Sem informações.")

    except Exception as e:
        return f"Erro câmbio: {e}"


# ==========================================
# 9. SERPAPI — HISTÓRIA
# ==========================================
def pesquisar_historia(destino):
    print(f"📚 Pesquisando história de {destino}...")

    try:
        params = {
            "engine": "google",
            "q": f"história de {destino}",
            "api_key": SERPAPI_KEY,
            "hl": "pt",
            "gl": "br"
        }

        results = GoogleSearch(params).get_dict()
        print_estruturado("RESULTADO SERPAPI (HISTÓRIA)", results)

        org = results.get("organic_results", [])
        if not org:
            return "História não encontrada."

        return "\n".join(
            f"- {item.get('title')}: {item.get('snippet', '')}"
            for item in org[:3]
        )

    except:
        return "Erro história."


# ==========================================
# 10. ORQUESTRADOR COMPLETO
# ==========================================
def agente_de_viagens(origem_usuario, destino_usuario):
    # 1. LLM escolhe datas e interesses
    data_ida, data_volta, interesses = gerar_dados_viagem(origem_usuario, destino_usuario)

    # 2. Descobrir aeroportos
    codigo_origem = descobrir_aeroporto(origem_usuario)
    codigo_destino = descobrir_aeroporto(destino_usuario)

    # 3. Consultar dados reais
    voos = buscar_voos_reais(codigo_origem, codigo_destino, data_ida, data_volta)
    hoteis = buscar_hoteis_reais(destino_usuario, data_ida, data_volta)
    atracoes = pesquisar_atracoes(destino_usuario, interesses)
    cambio = buscar_cambio(destino_usuario)
    historia = pesquisar_historia(destino_usuario)

    # 4. Gerar roteiro final
    print("\n🤖  Gerando roteiro final...\n")
    llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.5)

    prompt = f"""
    Gere um roteiro extremamente detalhado para uma viagem de {origem_usuario} para {destino_usuario}.

    DADOS REAIS:
    ✈️ Voos:
    {voos}

    🏨 Hotéis:
    {hoteis}

    🎡 Atrações:
    {atracoes}

    💱 Câmbio:
    {cambio}

    📚 História:
    {historia}

    DATAS:
    - Ida: {data_ida}
    - Volta: {data_volta}

    Interesses: {interesses}

    Monte:
    - Roteiro dia a dia baseado nos dados reais
    - Explicações culturais e históricas
    - Custos aproximados
    - Justificativa da escolha do roteiro
    """

    return llm.invoke(prompt).content


# ==========================================
# 11. TESTE FINAL
# ==========================================
ORIGEM = "São Paulo"
DESTINO = "Japão"

roteiro = agente_de_viagens(ORIGEM, DESTINO)
print("="*80)
print(roteiro)
print("="*80)
# Out:
# 🤔 Identificando aeroporto principal de: São Paulo...
#    ✅ Código encontrado: GRU
# 🤔 Identificando aeroporto principal de: Japão...
#    ✅ Código encontrado: NRT
# ✈️  Buscando voos (GRU -> NRT)...
#
# 🟦 RESULTADO SERPAPI (VOOS)
#
# {
#     "error": "`outbound_date` cannot be in the past."
# }
# 🏨  Buscando hotéis em Japão...
#
# 🟦 RESULTADO SERPAPI (HOTÉIS)
#
# {
#     "error": "`check_in_date` cannot be in the past."
# }
# 🔍  Pesquisando atrações em Japão...
#
# 🟦 RESULTADO SERPAPI (ATRAÇÕES)
#
# {
#     "search_metadata": {
#         "id": "6930af3f7223f4b81916d84e",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/cefed78b98f75002/6930af3f7223f4b81916d84e.json",
#         "pixel_position_endpoint": "https://serpapi.com/searches/cefed78b98f75002/6930af3f7223f4b81916d84e.json_with_pixel_position",
#         "created_at": "2025-12-03 21:44:31 UTC",
#         "processed_at": "2025-12-03 21:44:31 UTC",
#         "google_url": "https://www.google.com/search?q=melhores+atra%C3%A7%C3%B5es+Jap%C3%A3o+Cultura+%28templos%2C+santu%C3%A1rios%2C+hist%C3%B3ria%29%2C+Gastronomia+%28sushi%2C+ramen%2C+culin%C3%A1ria+local%29%2C+Natureza+%28folhas+de+outono%2C+jardins%2C+paisagens%29%2C+Modernidade+%28tecnologia%2C+arranha-c%C3%A9us%2C+vida+urbana%29%2C+Compras+%28eletr%C3%B4nicos%2C+moda%2C+souvenirs%29%2C+Bem-estar+%28experi%C3%AAncia+em+onsens%29&oq=melhores+atra%C3%A7%C3%B5es+Jap%C3%A3o+Cultura+%28templos%2C+santu%C3%A1rios%2C+hist%C3%B3ria%29%2C+Gastronomia+%28sushi%2C+ramen%2C+culin%C3%A1ria+local%29%2C+Natureza+%28folhas+de+outono%2C+jardins%2C+paisagens%29%2C+Modernidade+%28tecnologia%2C+arranha-c%C3%A9us%2C+vida+urbana%29%2C+Compras+%28eletr%C3%B4nicos%2C+moda%2C+souvenirs%29%2C+Bem-estar+%28experi%C3%AAncia+em+onsens%29&hl=pt&gl=br&sourceid=chrome&ie=UTF-8",
#         "raw_html_file": "https://serpapi.com/searches/cefed78b98f75002/6930af3f7223f4b81916d84e.html",
#         "total_time_taken": 1.42
#     },
#     "search_parameters": {
#         "engine": "google",
#         "q": "melhores atrações Japão Cultura (templos, santuários, história), Gastronomia (sushi, ramen, culinária local), Natureza (folhas de outono, jardins, paisagens), Modernidade (tecnologia, arranha-céus, vida urbana), Compras (eletrônicos, moda, souvenirs), Bem-estar (experiência em onsens)",
#         "google_domain": "google.com",
#         "hl": "pt",
#         "gl": "br",
#         "device": "desktop"
#     },
#     "search_information": {
#         "query_displayed": "melhores atrações Japão Cultura (templos, santuários, história), Gastronomia (sushi, ramen, culinária local), Natureza (folhas de outono, jardins, paisagens), Modernidade (tecnologia, arranha-céus, vida urbana), Compras (eletrônicos, moda, souvenirs), Bem-estar (experiência em onsens)",
#         "total_results": 112,
#         "time_taken_displayed": 0.58,
#         "organic_results_state": "Results for exact spelling"
#     },
#     "related_questions": [
#         {
#             "question": "Quais são os melhores lugares para visitar no Japão?",
#             "type": "ai_overview",
#             "text_blocks": [
#                 {
#                     "type": "paragraph",
#                     "snippet": "Os melhores lugares para visitar no Japão incluem as cidades modernas de Tóquio e Osaka, a tradicional Kyoto e cidades com forte significado histórico como Hiroshima e Nara. Outras opções populares são o icônico Monte Fuji, o Castelo de Himeji, o distrito de Akihabara em Tóquio para cultura pop e o Santuário Fushimi Inari em Kyoto.",
#                     "snippet_highlighted_words": [
#                         "as cidades modernas de Tóquio e Osaka, a tradicional Kyoto e cidades com forte significado histórico como Hiroshima e Nara"
#                     ],
#                     "reference_indexes": [
#                         0,
#                         1,
#                         2,
#                         6,
#                         11,
#                         12,
#                         13,
#                         14,
#                         15
#                     ]
#                 },
#                 {
#                     "type": "paragraph",
#                     "snippet": "Cidades e regiões imperdíveis"
#                 },
#                 {
#                     "type": "list",
#                     "list": [
#                         {
#                             "title": "Tóquio:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=T%C3%B3quio&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegQIcxAB",
#                             "snippet": "A capital é uma metrópole vibrante com arranha-céus, tecnologia e o famoso cruzamento de Shibuya. O bairro de Akihabara é um paraíso geek com lojas de anime, mangá e eletrônicos.",
#                             "reference_indexes": [
#                                 0,
#                                 2,
#                                 6,
#                                 11,
#                                 12,
#                                 13,
#                                 14,
#                                 15
#                             ]
#                         },
#                         {
#                             "title": "Kyoto:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Kyoto&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegUIjgEQAQ",
#                             "snippet": "A antiga capital oferece um mergulho na tradição japonesa, com templos deslumbrantes, jardins e o distrito de Gion, conhecido pelas casas de chá e geishas. O Santuário Fushimi Inari, com seus milhares de portões torii vermelhos, é um dos locais mais famosos.",
#                             "reference_indexes": [
#                                 0,
#                                 1,
#                                 6
#                             ]
#                         },
#                         {
#                             "title": "Osaka:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Osaka&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegUImQEQAQ",
#                             "snippet": "Conhecida por sua atmosfera agitada, restaurantes deliciosos e vida noturna. O bairro de Dotonbori é um ponto de destaque.",
#                             "reference_indexes": [
#                                 0,
#                                 4,
#                                 6,
#                                 8
#                             ]
#                         },
#                         {
#                             "title": "Hiroshima:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Hiroshima&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegUImAEQAQ",
#                             "snippet": "Uma cidade com um significado histórico profundo, o Parque Memorial da Paz e o Museu do Memorial da Paz são visitas essenciais para entender o passado do Japão.",
#                             "reference_indexes": [
#                                 0,
#                                 1,
#                                 6,
#                                 9
#                             ]
#                         },
#                         {
#                             "title": "Nara:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Nara&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegQIehAB",
#                             "snippet": "Fácil de acessar como um passeio de um dia a partir de Kyoto, Nara é famosa por seu parque com cervos amigáveis e o impressionante Templo Todai-ji.",
#                             "reference_indexes": [
#                                 0,
#                                 5,
#                                 6
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "type": "paragraph",
#                     "snippet": "Atrações icônicas e experiências únicas"
#                 },
#                 {
#                     "type": "list",
#                     "list": [
#                         {
#                             "title": "Monte Fuji:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Monte+Fuji&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegQIcBAB",
#                             "snippet": "O símbolo mais icônico do Japão, que pode ser admirado de vários pontos ou até mesmo escalado.",
#                             "reference_indexes": [
#                                 6
#                             ]
#                         },
#                         {
#                             "title": "Castelo de Himeji:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Castelo+de+Himeji&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegQIchAB",
#                             "snippet": "Considerado o mais belo exemplo preservado de arquitetura de castelo japonês e Patrimônio Mundial da UNESCO.",
#                             "reference_indexes": [
#                                 6
#                             ]
#                         },
#                         {
#                             "title": "Ilha de Naoshima:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Ilha+de+Naoshima&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegQIdxAB",
#                             "snippet": "Uma ilha dedicada à arte e arquitetura contemporânea, com museus e instalações ao ar livre.",
#                             "reference_indexes": [
#                                 3,
#                                 7
#                             ]
#                         },
#                         {
#                             "title": "Shirakawa-go:",
#                             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Shirakawa-go&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQxccNegQIeRAB",
#                             "snippet": "Uma vila tradicional com casas no estilo gassho-zukuri, com telhados inclinados para suportar a neve.",
#                             "reference_indexes": [
#                                 3,
#                                 10
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "references": [
#                 {
#                     "title": "Perfect itineraries for JAPAN! Which cities to visit? 7, 12, 15 and 20 days!",
#                     "link": "https://www.youtube.com/watch?v=cFDfCsaP5M0&t=25",
#                     "snippet": "24 de set. de 2024 — todas as dicas para você finalmente conseguir montar pelo menos na sua cabeça. inicial o seu roteiro pelo Japão ...",
#                     "source": "YouTube · Gabriel Lorenzi - Dicas de Viagem",
#                     "index": 0
#                 },
#                 {
#                     "title": "Japão - dicas essenciais para sua viagem! - Guia de Destinos",
#                     "link": "https://guia.melhoresdestinos.com.br/categorias/japao.html#:~:text=Roteiro%20pelo%20Jap%C3%A3o:%20quanto%20tempo,uma%20hist%C3%B3ria%20dura%20e%20comovente.",
#                     "snippet": "Roteiro pelo Japão: quanto tempo ficar Como o Japão está do outro lado do mundo, eu recomendo que seu roteiro tenha pelo menos 10 ...",
#                     "source": "Melhores Destinos",
#                     "index": 1
#                 },
#                 {
#                     "title": "Cidades do Japão: 33 lugares incríveis para conhecer no país da Ásia",
#                     "link": "https://www.hostelworld.com/blog/br/cidades-do-japao/#:~:text=4.,Akihabara&text=Chamado%20especial%20para%20os%20nerds,N%C3%A3o%20diga%20que%20n%C3%A3o%20avisamos%E2%80%A6",
#                     "snippet": "26 de out. de 2017 — 4. Akihabara. ... Chamado especial para os nerds! Akihabara ganhou fama como a capital geek do mundo. Do anime e...",
#                     "source": "Hostelworld",
#                     "index": 2
#                 },
#                 {
#                     "title": "Cidades do Japão: destinos imperdíveis para sua viagem",
#                     "link": "https://segredosdeviagem.com.br/cidades-do-japao/#:~:text=Cidades%20do%20Jap%C3%A3o%20no%20nosso,Sim%2C%20elas%20existem!",
#                     "snippet": "Cidades do Japão no nosso roteiro Nesses post contemplaremos as cidades japonesas listadas abaixo. Se quiser ir direto para o trec...",
#                     "source": "Segredos de Viagem",
#                     "index": 3
#                 },
#                 {
#                     "title": "O que fazer no Japão: saiba quais são as melhores cidades",
#                     "link": "https://vaipromundo.com.br/blog/o-que-fazer-no-japao-saiba-quais-sao-as-melhores-cidades/#:~:text=Quioto%20tamb%C3%A9m%20est%C3%A1%20entre%20as%20melhores%20cidades,o%20Fushimi%20Inari%2Dtaisha%20com%20seus%20toriis%20vermelhos.",
#                     "snippet": "2 de fev. de 2024 — Quioto também está entre as melhores cidades para quem quer fazer um bom turismo no Japão. Lá, recomendamos passe...",
#                     "source": "vaipromundo.com.br",
#                     "index": 4
#                 },
#                 {
#                     "title": "Japão: lista com 12 cidades imperdíveis que você precisa ...",
#                     "link": "https://ideiasnamala.com/japao-cidades-imperdiveis/#:~:text=Nara:%20um%20bate%20e%20volta,a%2045%20minutos%20de%20trem.",
#                     "snippet": "Nara: um bate e volta mais que especial Nara foi a primeira capital fixa do Japão, ao longo do século VIII. A cidade é conhecida p...",
#                     "source": "Ideias na mala",
#                     "index": 5
#                 },
#                 {
#                     "title": "Pontos Turísticos no Japão: 10 Lugares Imperdíveis para Visitar",
#                     "link": "https://www.airalo.com/pt-BR/blog/pontos-turisticos-do-japao",
#                     "snippet": "26 de jun. de 2025 — Revista * Monte Fuji. O Monte Fuji é o símbolo mais reconhecido do Japão, e uma das montanhas mais fotografadas...",
#                     "source": "Airalo",
#                     "index": 6
#                 },
#                 {
#                     "title": "4 destinos diferentes e pouco explorados no Japão",
#                     "link": "https://segredosdeviagem.com.br/destinos-diferentes-no-japao/#:~:text=Naoshima,art%C3%ADsticos%20e%20inusitados%20na%20lista.",
#                     "snippet": "Naoshima. Criança feliz em Naoshima! Não canso de dizer que Naoshima foi um dos meus destinos queridinhos da viagem, e um dos que ...",
#                     "source": "Segredos de Viagem",
#                     "index": 7
#                 },
#                 {
#                     "title": "10 MELHORES Passeios turísticos em Japão (ATUALIZADO 2025)",
#                     "link": "https://www.tripadvisor.com.br/Attractions-g294232-Activities-c42-t139-Japan.html#:~:text=20.,(3%20bares%2C%206%20sabores)&text=Osaka%20%C3%A9%20conhecida%20por%20sua,%22cidade%20festiva%22%20do%20Jap%C3%A3o.",
#                     "snippet": "20. Osaka Bar Hopping Night Walking Tour em Namba (3 bares, 6 sabores) ... Osaka é conhecida por sua agitada vida noturna e delici...",
#                     "source": "Tripadvisor",
#                     "index": 8
#                 },
#                 {
#                     "title": "10 MELHORES Locais históricos em Japão (ATUALIZADO 2025)",
#                     "link": "https://www.tripadvisor.com.br/Attractions-g294232-Activities-c47-t17-Japan.html#:~:text=8.,Hiroshima%20Peace%20Memorial%20Park&text=O%20lindo%20parque%20que%20abriga,horas%20para%20caminhar%20pelo...",
#                     "snippet": "8. Hiroshima Peace Memorial Park. ... O lindo parque que abriga o memorial da paz e o museu do memorial da paz. Reserve algumas ho...",
#                     "source": "Tripadvisor",
#                     "index": 9
#                 },
#                 {
#                     "title": "MARAVILHAS DO JAPÃO | Os Lugares Mais Belos para Visitar no ...",
#                     "link": "https://www.youtube.com/watch?v=-zaDkLbzc1U&t=65",
#                     "snippet": "13 de fev. de 2025 — venha conosco nesta jornada para explorar as maravilhas mais surpreendentes do Japão. um país que nunca deixa de...",
#                     "source": "YouTube · Meu Planeta Irreal TV BR",
#                     "index": 10
#                 },
#                 {
#                     "title": "Turismo no Japão: Principais Destinos, Épocas e Curiosidades - Cursos Gratuitos Idiomas, Concursos, Enem e Muito Mais",
#                     "link": "https://kultivi.com/blog/idiomas/turismo-no-japao-principais-destinos-epocas-e-curiosidades#:~:text=1.%20T%C3%B3quio:%20a%20capital%20vibrante%20A%20capital,dos%20f%C3%A3s%20de%20eletr%C3%B4nicos%20e%20cultura%20geek.",
#                     "snippet": "10 de out. de 2025 — 1. Tóquio: a capital vibrante A capital japonesa ( Terra do Sol Nascente ) é uma metrópole futurista repleta de ...",
#                     "source": "Kultivi",
#                     "index": 11
#                 },
#                 {
#                     "title": "Japão: tudo o que você precisa saber sobre o destino do momento — Leroy Viagens",
#                     "link": "https://www.leroyviagens.com.br/blog/2025/japao#:~:text=T%C3%B3quio%2C%20a%20capital%20em%20movimento%20T%C3%B3quio%20%C3%A9,(%20Idioma:%20Japon%C3%AAs%20)%20em%20sua%20ess%C3%AAncia.",
#                     "snippet": "2 de abr. de 2025 — Tóquio, a capital em movimento Tóquio é uma cidade onde o futuro e o passado coexistem harmoniosamente. Em um mes...",
#                     "source": "Leroy Viagens",
#                     "index": 12
#                 },
#                 {
#                     "title": "O que fazer no Japão: dicas para sua primeira viagem!",
#                     "link": "https://www.seguroviagem.srv.br/blog/viagem-para-japao/#:~:text=Como%20toda%20capital%2C%20Tokyo%20%C3%A9%20refer%C3%AAncia%20em,que%20atraem%20muitos%20turistas%20por%20sua%20beleza.",
#                     "snippet": "18 de out. de 2022 — Como toda capital, Tokyo é referência em modernidade e estilo. Conceituada com arranha-céus, a cidade é contempl...",
#                     "source": "seguroviagem.srv.br",
#                     "index": 13
#                 },
#                 {
#                     "title": "Quais os pontos turísticos mais visitados do Japão",
#                     "link": "https://www.adventureclub.com.br/blog/quais-os-pontos-turisticos-mais-visitados-do-japao/#:~:text=Shibuya%20A%20capital%20japonesa%20(%20terra%20do,as%20novidades%20do%20com%C3%A9rcio%20local%20e%20global.",
#                     "snippet": "9 de mar. de 2015 — Shibuya A capital japonesa ( terra do sol nascente ) , Tóquio, abriga uma das regiões mais populosas do mundo: Sh...",
#                     "source": "adventureclub.com.br",
#                     "index": 14
#                 },
#                 {
#                     "title": "Japão - TITO ELBLING VIAGENS",
#                     "link": "https://titoelbling.pt/destinations/japao/#:~:text=T%C3%B3quio:%20A%20Metr%C3%B3pole%20do%20Futuro%20Come%C3%A7a%20a,seu%20cruzamento%20movimentado%20e%20vida%20noturna%20vibrante.",
#                     "snippet": "Tóquio: A Metrópole do Futuro Começa a tua jornada em Tóquio, a capital do Japão e uma das cidades mais dinâmicas do mundo. Aqui,",
#                     "source": "tito elbling viagens",
#                     "index": 15
#                 }
#             ],
#             "next_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D"
#         },
#         {
#             "question": "Quanto custa ficar 7 dias no Japão?",
#             "type": "featured_snippet",
#             "snippet": "Um passe de 7 dias custa cerca de R$ 1.700.",
#             "title": "R$ 1.700",
#             "link": "https://www.assistcard.com/br/quanto-custa-viagem-para-japao#:~:text=Um%20passe%20de%207%20dias%20custa%20cerca%20de%20R%24%201.700.",
#             "displayed_link": "https://www.assistcard.com › quanto-custa-viagem-para-j...",
#             "source_logo": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/d98748379274d814103d38e452b852e842d475980d46b8a33ff825c8586f950e.png",
#             "next_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D%3D"
#         },
#         {
#             "question": "Qual é a principal cultura do Japão?",
#             "type": "featured_snippet",
#             "snippet": "Cultura pop: O Japão é conhecido por sua cultura pop vibrante, que inclui mangás, animes, música J-pop, moda excêntrica e jogos eletrônicos.",
#             "title": "Quais sao as principais caracteristicas da cultura do povo... - Brasil Escola",
#             "link": "https://brasilescola.uol.com.br/tire-duvidas/quais-sao-as-principais-caracteristicas-da-cultura-do-povo-j/3777.html#:~:text=Cultura%20pop%3A%20O%20Jap%C3%A3o%20%C3%A9,moda%20exc%C3%AAntrica%20e%20jogos%20eletr%C3%B4nicos.",
#             "displayed_link": "https://brasilescola.uol.com.br › tire-duvidas › quais-sao-...",
#             "source_logo": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/d98748379274d814103d38e452b852e8b463cc235683a4634306c65d61ff03b2.png",
#             "next_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D%3D"
#         },
#         {
#             "question": "Qual é o ponto turístico mais visitado do Japão?",
#             "type": "featured_snippet",
#             "snippet": "1. Monte Fuji. Símbolo máximo do Japão, o Monte Fuji é a montanha mais alta do país, com 3.776 metros de altitude. Localizado a oeste de Tóquio, é um destino popular para escaladas durante o verão e oferece vistas deslumbrantes durante todo o ano.",
#             "title": "Monte Fuji",
#             "link": "https://aerotur.com.br/pontos-turisticos-japao/#:~:text=1.,deslumbrantes%20durante%20todo%20o%20ano.",
#             "displayed_link": "https://aerotur.com.br › pontos-turisticos-japao",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWRJ-WRbD_CqyMCUkd2NcZbPYylNUN5dPgzznqp41Fkg&s",
#             "source_logo": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/d98748379274d814103d38e452b852e8bad33321bbde6b10787254f0ada5ddde.png",
#             "next_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3

#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.tripadvisor.com.br/Attractions-g294232-Activities-Japan.html&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECB4QAQ",
#             "displayed_link": "https://www.tripadvisor.com.br › Ásia › Japão",
#             "thumbnail": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdaedc0538b023955ffffcd11cba1848e664.jpeg",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdae17fe1ec7978b534cac4050bd25642603.png",
#             "snippet": "Confira atrações e atividades imperdíveis: Santuário de Fushimi Inari, Pavilhão de Ouro (Kinkaku-ji), Excursões culturais, Passeios na natureza e vida selvagem.",
#             "snippet_highlighted_words": [
#                 "atrações",
#                 "Santuário",
#                 "natureza",
#                 "vida"
#             ],
#             "source": "Tripadvisor"
#         },
#         {
#             "position": 3,
#             "title": "TUDO SOBRE O JAPÃO: O GUIA DEFINITIVO PARA A ...",
#             "link": "https://rodsnaideia.com/destinos/tudo-sobre-o-japao-o-guia-definitivo-para-a-sua-viagem/",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://rodsnaideia.com/destinos/tudo-sobre-o-japao-o-guia-definitivo-para-a-sua-viagem/&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECDoQAQ",
#             "displayed_link": "https://rodsnaideia.com › destinos › tudo-sobre-o-japao...",
#             "thumbnail": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdae1e0536f3e5656f32bcd653b62fc9f5bf.jpeg",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdae42d51c0b8110c5015494cf81d122ae95.png",
#             "snippet": "Zonas como Shibuya, Harajuku, Akihabara e Asakusa oferecem uma mistura incrível de centros de compras, cultura pop, arranha-céus e templos históricos. A ...",
#             "snippet_highlighted_words": [
#                 "compras",
#                 "cultura",
#                 "arranha",
#                 "céus",
#                 "templos"
#             ],
#             "source": "Rodsnaideia"
#         },
#         {
#             "position": 4,
#             "title": "Japão: cultura, templos, tecnologia e paisagens únicas",
#             "link": "https://vaipromundo.com.br/destino/asia/japao/",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://vaipromundo.com.br/destino/asia/japao/&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECDUQAQ",
#             "displayed_link": "https://vaipromundo.com.br › Destinations › Ásia",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdae50f79ddcaf4667b18602a6bcba8e7a68.png",
#             "snippet": "Explore o Japão: templos milenares, tecnologia de ponta, culinária única, paisagens deslumbrantes e cultura fascinante. Planeje sua viagem...",
#             "snippet_highlighted_words": [
#                 "Japão",
#                 "templos",
#                 "tecnologia",
#                 "culinária",
#                 "paisagens",
#                 "cultura"
#             ],
#             "missing": [
#                 "(sushi,",
#                 "ramen,",
#                 "(folhas",
#                 "outono,",
#                 "jardins,",
#                 "urbana),",
#                 "Compras",
#                 "(eletrônicos,",
#                 "souvenirs),",
#                 "onsens)"
#             ],
#             "source": "Vai Pro Mundo Viagens"
#         },
#         {
#             "position": 5,
#             "title": "As principais atrações turísticas do Japão",
#             "link": "https://www.terra.com.br/vida-e-estilo/turismo/as-principais-atracoes-turisticas-do-japao,d70a2f88beb30a7998782c59c218b5b0xiftzgea.html",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.terra.com.br/vida-e-estilo/turismo/as-principais-atracoes-turisticas-do-japao,d70a2f88beb30a7998782c59c218b5b0xiftzgea.html&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECDQQAQ",
#             "displayed_link": "https://www.terra.com.br › Vida e Estilo › Turismo",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdaedeb9d5ed47ef47f773a7ca35ea296139.png",
#             "date": "24 de out. de 2025",
#             "snippet": "Os pontos turísticos japoneses se destacam por unir o passado samurai às grandes realizações tecnológicas atuais. Conheça os cartões-postais ...",
#             "missing": [
#                 "(sushi,",
#                 "ramen,",
#                 "Modernidade",
#                 "(tecnologia,",
#                 "Compras",
#                 "moda,",
#                 "souvenirs),",
#                 "Bem-",
#                 "estar"
#             ],
#             "source": "Terra"
#         },
#         {
#             "position": 6,
#             "title": "Destinos no Japão - confira 11 que são imperdíveis para ...",
#             "link": "https://www.terramundi.com.br/blog/destinos-no-japao-11-imperdiveis/",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.terramundi.com.br/blog/destinos-no-japao-11-imperdiveis/&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECDwQAQ",
#             "displayed_link": "https://www.terramundi.com.br › Início › Post",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdaef1f471b9bda1296149ce483cc5e701cf.png",
#             "date": "29 de jan. de 2019",
#             "snippet": "Selecionamos 11 lugares imperdíveis deste país que encanta a todos. Confira e conheça os melhores lugares para visitar no Japão!",
#             "snippet_highlighted_words": [
#                 "melhores",
#                 "Japão"
#             ],
#             "missing": [
#                 "santuários,",
#                 "(folhas",
#                 "outono,",
#                 "(tecnologia,",
#                 "Compras",
#                 "(eletrônicos,",
#                 "moda,",
#                 "souvenirs),",
#                 "onsens)"
#             ],
#             "source": "Terramundi Viagens"
#         },
#         {
#             "position": 7,
#             "title": "O melhor roteiro de 10 dias pelo Japão",
#             "link": "https://translate.google.com/translate?u=https://www.designerjourneys.com/blog/ultimate-10-day-japan-tour-itinerary/&hl=pt&sl=en&tl=pt&client=srp",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://translate.google.com/translate%3Fu%3Dhttps://www.designerjourneys.com/blog/ultimate-10-day-japan-tour-itinerary/%26hl%3Dpt%26sl%3Den%26tl%3Dpt%26client%3Dsrp&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECDkQAQ",
#             "displayed_link": "https://www.designerjourneys.com › blog › ultimate-10...",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdae4bf46e07af7d9d72afac8eb1c65ffb34.png",
#             "date": "16 de set. de 2024",
#             "snippet": "Descubra os tesouros escondidos do Japão com o itinerário abrangente de 10 dias da Designer Journeys, de templos antigos a cidades de alta ...",
#             "snippet_highlighted_words": [
#                 "Japão",
#                 "templos"
#             ],
#             "rich_snippet": {
#                 "top": {
#                     "detected_extensions": {
#                         "rating": 4.4,
#                         "reviews": 19
#                     },
#                     "extensions": [
#                         "4,4(19)"
#                     ]
#                 }
#             },
#             "source": "Designer Journeys"
#         },
#         {
#             "position": 8,
#             "title": "O que fazer no Japão: 20 lugares incríveis",
#             "link": "https://www.civitatis.com/blog/pt-br/o-que-fazer-japao/?srsltid=AfmBOorBesHoWu4x-1Roq0sjRx2nNPg3b_FTtWTFeHSmH6pd1xD_Qa0K",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.civitatis.com/blog/pt-br/o-que-fazer-japao/%3Fsrsltid%3DAfmBOorBesHoWu4x-1Roq0sjRx2nNPg3b_FTtWTFeHSmH6pd1xD_Qa0K&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECDgQAQ",
#             "displayed_link": "https://www.civitatis.com › pt-br › o-que-fazer-japao",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdaef5dea76e86798e4cc6fc5995712c9b50.png",
#             "date": "5 de nov. de 2025",
#             "snippet": "Os amantes de anime, mangá ou tecnologia vão adorar conhecer Akihabara, um paraíso na Terra bem no centro de Tóquio. Este bairro é o epicentro ...",
#             "snippet_highlighted_words": [
#                 "tecnologia",
#                 "bem"
#             ],
#             "source": "Civitatis"
#         },
#         {
#             "position": 9,
#             "title": "As Experiências Culturais no Japão | Guide",
#             "link": "https://www.japan.travel/pt/guide/cultural-experiences/",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.japan.travel/pt/guide/cultural-experiences/&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECDsQAQ",
#             "displayed_link": "https://www.japan.travel › guide › cultural-experiences",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdaeeb3a922f7b1c27dd634f9c68f9532b21.png",
#             "snippet": "Como vivenciar o patrimônio cultural do Japão através de atividades tradicionais, de cerimônias de chá, percussão taiko e fazer sushi, a estadias em ...",
#             "snippet_highlighted_words": [
#                 "Japão",
#                 "sushi"
#             ],
#             "missing": [
#                 "ramen,",
#                 "Modernidade",
#                 "(tecnologia,",
#                 "arranha-",
#                 "céus,",
#                 "urbana),",
#                 "(eletrônicos,",
#                 "souvenirs),"
#             ],
#             "source": "Japan National Tourism Organization"
#         },
#         {
#             "position": 10,
#             "title": "Japão, o que fazer: todos os lugares que não pode perder",
#             "link": "https://www.costacruzeiros.com/costa-club/magazine/viagem/o-que-fazer-japao.html",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.costacruzeiros.com/costa-club/magazine/viagem/o-que-fazer-japao.html&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQFnoECDcQAQ",
#             "displayed_link": "https://www.costacruzeiros.com › magazine › viagem",
#             "favicon": "https://serpapi.com/searches/6930af3f7223f4b81916d84e/images/47a986a0c93c91a747898b94409cbdae92d87ec5f55e60a7b24f777da64a8543.png",
#             "date": "14 de fev. de 2020",
#             "snippet": "Em Kyoto, existem vários templos: o Templo Ninnaji é um Patrimônio Mundial da UNESCO, o Templo Ryoanji inclui o jardim de rochas mais famoso do ...",
#             "snippet_highlighted_words": [
#                 "templos",
#                 "Templo",
#                 "Templo",
#                 "jardim"
#             ],
#             "missing": [
#                 "Gastronomia",
#                 "outono,",
#                 "(eletrônicos,",
#                 "moda,",
#                 "souvenirs),"
#             ],
#             "source": "Costa Cruzeiros"
#         }
#     ],
#     "related_searches": [
#         {
#             "block_position": 1,
#             "items": [
#                 {
#                     "name": "Fushimi Inari-taisha",
#                     "image": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRctP_BDNDLka64zjpdMYdmR_ujNS4tZt9wJZ6gcA6p6GWrjpOzqx3m&s=0",
#                     "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=fushimi+inari+taisha&stick=H4sIAAAAAAAAAOMwVOLUz9U3MM1JKcr9xciwgYXhFQs3F0LsFQsXFweIl5xdbACXMjJJik-H8wyz80zKX7HwcHGB5QrKc7NyEEotMowRPEOLvOQKhFxlnjHCGHNj8wpThMrC-GzLRawiaaXFGZm5mQqZeYlFmQoliZnFGYm32CQZdi_q-Mniut9wo6Xxxk1ij7ez_3L_W5s2Y-UiDiX_0pKixGKFgtTi4nwgXZKYm3R4ZS6IX1iaWZxYlJi7goMRABvBBRz6AAAA&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlI
link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=arashiyama&stick=H4sIAAAAAAAAAOMwVOLUz9U3MLLIMM75xciwgYXhFQs3F1jMNCelKPcVCxcXB4iXnF1sAJcyMkmKT4fzDLPzTMpfsfBwcYHlCspzs3IQSkEmI5Ra5CVXIOQq84wRxpgbm1eYIlQWxmdbLmLlSixKLM7IrEzMTbzFJsmwe1HHTxbX_YYbLY03bhJ7vJ39l_vf2rQZKxdxKPmXlgCVKhSkFhfnA-mSxNykwytzQfzC0sxioDG5KzgYAcDNX9vwAAAA&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQs9oBKAB6BAg2ECM",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=br&google_domain=google.com&hl=pt&q=arashiyama&stick=H4sIAAAAAAAAAOMwVOLUz9U3MLLIMM75xciwgYXhFQs3F1jMNCelKPcVCxcXB4iXnF1sAJcyMkmKT4fzDLPzTMpfsfBwcYHlCspzs3IQSkEmI5Ra5CVXIOQq84wRxpgbm1eYIlQWxmdbLmLlSixKLM7IrEzMTbzFJsmwe1HHTxbX_YYbLY03bhJ7vJ39l_vf2rQZKxdxKPmXlgCVKhSkFhfnA-mSxNykwytzQfzC0sxioDG5KzgYAcDNX9vwAAAA"
#                 }
#             ]
#         },
#         {
#             "block_position": 1,
#             "query": "Pontos turísticos do Japão Tóquio",
#             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Pontos+tur%C3%ADsticos+do+Jap%C3%A3o+T%C3%B3quio&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQ1QJ6BAhVEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=br&google_domain=google.com&hl=pt&q=Pontos+tur%C3%ADsticos+do+Jap%C3%A3o+T%C3%B3quio"
#         },
#         {
#             "block_position": 1,
#             "query": "Pontos turísticos do Japão mais visitados",
#             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Pontos+tur%C3%ADsticos+do+Jap%C3%A3o+mais+visitados&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQ1QJ6BAhXEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=br&google_domain=google.com&hl=pt&q=Pontos+tur%C3%ADsticos+do+Jap%C3%A3o+mais+visitados"
#         },
#         {
#             "block_position": 1,
#             "query": "Pontos turísticos do Japão Monte Fuji",
#             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Pontos+tur%C3%ADsticos+do+Jap%C3%A3o+Monte+Fuji&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQ1QJ6BAhZEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=br&google_domain=google.com&hl=pt&q=Pontos+tur%C3%ADsticos+do+Jap%C3%A3o+Monte+Fuji"
#         },
#         {
#             "block_position": 1,
#             "query": "Turismo no Japão resumo",
#             "link": "https://www.google.com/search?sca_esv=8dfe9edb86176f37&hl=pt&gl=br&q=Turismo+no+Jap%C3%A3o+resumo&sa=X&ved=2ahUKEwjX0cbwsaKRAxVgj2oFHX1dOlIQ1QJ6BAhWEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=br&google_domain=google.com&hl=pt&q=Turismo+no+Jap%C3%A3o+resumo"
#         },
#         {
#             "block_position": 1,
#             "query": "Lugares do Japão para morar",
# ...
#         *   **Hakone Open-Air Museum:** Um museu de arte ao ar livre com esculturas em um belo cenário natural, com folhas de outono.
# *   **Noite:** **Experiência Onsen e Jantar Tradicional.**
#     *   **Bem-estar:** Relaxe em um *onsen* tradicional do seu *ryokan*.
#     *   **Gastronomia:** Desfrute de um jantar *kaiseki* (refeição tradicional japonesa de vários pratos) no seu *ryokan*.
# *   **Interesses Atendidos:** Natureza (paisagens, folhas de outono), Bem-estar (experiência em onsens), Gastronomia (culinária local), Cultura (ryokan).
#
# #### **Parte 2: Imersão na Cultura, História e Natureza de Quioto e Arredores**
#
# **Dia 6: Quarta-feira, 13 de Novembro de 2024 - Viagem para Quioto e Primeiros Contatos**
# *   **Manhã:** **Retorno de Hakone e Viagem para Quioto.**
#     *   **Transporte:** Desfrute de mais um pouco de Hakone, depois retorne a Odawara e pegue o Shinkansen (trem-bala) para Quioto (coberto pelo JR Pass).
#     *   **Hospedagem:** Check-in no hotel em Quioto.
# *   **Tarde:** **Gion - O Distrito das Gueixas.**
#     *   **Atividade:** Passeie pelas ruas históricas de **Gion**, o famoso distrito das gueixas. Com sorte, você poderá avistar uma *geiko* (gueixa de Quioto) ou *maiko* (aprendiz) a caminho de um compromisso.
#     *   **Cultura:** Visite o **Yasaka Shrine** e explore as ruas preservadas de **Hanamikoji Street**.
# *   **Noite:** **Pontocho Alley - Gastronomia.**
#     *   **Gastronomia:** Jantar em **Pontocho Alley**, um beco estreito e charmoso repleto de restaurantes e bares, alguns com vista para o Rio Kamo. Experimente um *okonomiyaki* ou *yakitori*.
# *   **Interesses Atendidos:** Cultura (história, gueixas), Gastronomia (culinária local).
#
# **Dia 7: Quinta-feira, 14 de Novembro de 2024 - Quioto Templos e Natureza (Arashiyama, Kinkaku-ji)**
# *   **Manhã:** **Arashiyama - Natureza e Templos Zen.**
#     *   **Atividade:** Visite o icônico **Bamboo Grove** de Arashiyama.
#     *   **Atividade:** Explore o **Tenryu-ji Temple**, um dos principais templos Zen de Quioto, com um jardim paisagístico espetacular, especialmente bonito com as folhas de outono.
#     *   **Atividade:** Atravesse a **Togetsukyo Bridge** para vistas panorâmicas do rio e das montanhas circundantes, que estarão em plena coloração de outono.
#     *   **Natureza:** "Passeios na natureza e vida selvagem."
# *   **Almoço:** Almoço na área de Arashiyama, com muitas opções de restaurantes vegetarianos e de tofu.
# *   **Tarde:** **Kinkaku-ji e Ryoan-ji - Ouro e Zen.**
#     *   **Atividade:** Visita ao **Kinkaku-ji (Pavilhão de Ouro)**, um Patrimônio Mundial da UNESCO, famoso por sua estrutura coberta de ouro e seu reflexo no lago. É um dos cartões postais do Japão.
#     *   **Dados Reais:** "Pavilhão de Ouro (Kinkaku-ji)."
#     *   **Atividade:** Visita ao **Ryoan-ji Temple**, famoso por seu jardim de pedras Zen, um local para contemplação e tranquilidade.
# *   **Noite:** Jantar em Quioto, talvez experimentando um *ramen* autêntico.
# *   **Interesses Atendidos:** Cultura (templos, história), Natureza (jardins, paisagens, folhas de outono), Gastronomia (ramen).
#
# **Dia 8: Sexta-feira, 15 de Novembro de 2024 - Quioto Santuários e Tradição (Fushimi Inari, Higashiyama)**
# *   **Manhã:** **Fushimi Inari Taisha - Milhares de Toriis.**
#     *   **Atividade:** Caminhe pelo **Philosopher's Path (Tetsugaku no Michi)**, um caminho tranquilo ao longo de um canal, ladeado por cerejeiras (e árvores de outono em novembro), conectando vários templos menores.
# *   **Noite:** **Experiência Cultural Opcional.**
#     *   **Cultura:** Considere participar de uma cerimônia do chá tradicional ou uma aula de culinária japonesa.
#     *   **Gastronomia:** Jantar de despedida em Quioto, talvez em um restaurante especializado em *kaiseki* para uma experiência mais refinada.
# *   **Interesses Atendidos:** Gastronomia (culinária local, mercados), Cultura (história, templos, cerimônia do chá), Natureza (jardins, folhas de outono).
#
# #### **Parte 3: Retorno a Tóquio, Compras e Despedida**
#
# **Dia 11: Segunda-feira, 18 de Novembro de 2024 - Viagem de Volta para Tóquio e Compras Finais**
# *   **Manhã:** **Viagem de Quioto para Tóquio.**
#     *   **Transporte:** Pegue o Shinkansen de Quioto de volta para Tóquio (coberto pelo JR Pass).
#     *   **Hospedagem:** Check-in no hotel em Tóquio.
# *   **Tarde:** **Compras e Exploração Urbana.**
#     *   **Atividade:** Explore áreas como **Ginza** para compras de luxo ou **Shinjuku** para eletrônicos e moda.
#     *   **Atividade:** Visite a área da **Tokyo Station**, com sua arquitetura impressionante e o shopping subterrâneo **Tokyo Character Street** (para souvenirs de personagens).
# *   **Noite:** **Jantar e Lazer.**
#     *   **Gastronomia:** Jantar em um restaurante à sua escolha, talvez revisitando um tipo de culinária que você gostou.
#     *   **Modernidade:** Explore as luzes de Shinjuku ou Shibuya à noite.
# *   **Interesses Atendidos:** Compras (eletrônicos, moda, souvenirs), Modernidade (arranha-céus), Gastronomia.
#
# **Dia 12: Terça-feira, 19 de Novembro de 2024 - Dia Livre em Tóquio ou Excursão Opcional**
# *   **Manhã/Tarde:** **Opções Flexíveis:**
#     *   **Cultura/Arte:** Visita ao **Ghibli Museum** (se conseguiu reservar com muita antecedência) ou ao **Tokyo National Museum** em Ueno.
#     *   **Modernidade/Futurismo:** Explore **Odaiba**, uma ilha artificial com arquitetura futurista, museus interativos (como o teamLab Borderless ou Planets), e a estátua de Gundam em tamanho real.
#     *   **Natureza/Tranquilidade:** Visite o **Koishikawa Korakuen Garden** ou o **Rikugien Garden**, dois dos mais belos jardins tradicionais de Tóquio, que estarão vibrantes com as cores do outono.
#     *   **Compras:** Revisitando suas áreas favoritas para compras finais de souvenirs ou itens específicos.
# *   **Noite:** Jantar de despedida em Tóquio, talvez em um restaurante com estrela Michelin ou um local com vista panorâmica.
# *   **Interesses Atendidos:** Todos os interesses, dependendo da escolha pessoal.
#
# **Dia 13: Quarta-feira, 20 de Novembro de 2024 - Despedida do Japão**
# *   **Manhã:** **Últimas Atividades e Compras.**
#     *   **Atividade:** Tempo livre para compras de última hora, visitar um café temático ou revisitar um local favorito.
#     *   **Gastronomia:** Desfrute de um último café da manhã japonês ou um almoço leve.
# *   **Tarde:** **Partida de Tóquio.**
#     *   **Transporte:** Check-out do hotel e transporte para o aeroporto de Narita (NRT) ou Haneda (HND) usando o Narita Express ou Keikyu Line.
#     *   **Voo:** Embarque no voo de volta para São Paulo.
# *   **Interesses Atendidos:** Compras (souvenirs), Gastronomia.
#
# **Dia 14: Quinta-feira, 21 de Novembro de 2024 - Chegada em São Paulo**
# *   **Manhã/Tarde:** Chegada ao Aeroporto Internacional de São Paulo (GRU).
#
# ---
#
# ### **Custos Aproximados (em JPY e BRL):**
#
# *   **Câmbio:** 100 JPY = 3,42 BRL
#
# 1.  **Voos (São Paulo - Tóquio - São Paulo):**
#     *   **Estimativa:** R$ 8.000 - R$ 15.000 por pessoa (ida e volta, econômica).
#     *   **Justificativa:** Nenhum voo foi encontrado nos dados, mas esta é uma faixa realista para voos diretos ou com uma escala para o Japão, especialmente reservando com antecedência.
#
# 2.  **Hospedagem (12 noites):**
#     *   **Estimativa:** 15.000 - 25.000 JPY por noite (hotel 3-4 estrelas, casal).
#     *   **Total em JPY:** 12 noites x 20.000 JPY/noite = 240.000 JPY
#     *   **Total em BRL:** 240.000 JPY * (3,42 BRL / 100 JPY) = **R$ 8.208**
#     *   **Justificativa:** Nenhum hotel foi encontrado nos dados, mas esta é uma faixa média para hotéis confortáveis em Tóquio e Quioto. O ryokan em Hakone pode ser um pouco mais caro.
#
# 3.  **Transporte Interno (JR Pass e Local):**
#     *   **JR Pass (14 dias):** Aprox. 50.000 JPY (valor pode variar).
#     *   **Transporte Local (Suica/Pasmo):** Aprox. 5.000 JPY por pessoa.
#     *   **Total em JPY:** 55.000 JPY
#     *   **Total em BRL:** 55.000 JPY * (3,42 BRL / 100 JPY) = **R$ 1.881**
#     *   **Justificativa:** O JR Pass é essencial para as viagens de Shinkansen. O transporte local cobre metrôs e ônibus não inclusos no JR Pass.
#
# 4.  **Alimentação (12 dias):**
#     *   **Estimativa:** 5.000 - 8.000 JPY por dia (café da manhã, almoço, jantar, lanches).
#     *   **Total em JPY:** 12 dias x 6.500 JPY/dia = 78.000 JPY
#     *   **Total em BRL:** 78.000 JPY * (3,42 BRL / 100 JPY) = **R$ 2.668**
#     *   **Justificativa:** Permite uma mistura de refeições casuais (ramen, udon, sushi de esteira) e algumas experiências mais elaboradas.
#
# 5.  **Atrações e Entradas:**
#     *   **Estimativa:** 500 - 1.500 JPY por atração.
#     *   **Total em JPY:** Aprox. 15.000 - 20.000 JPY por pessoa (considerando ~15 atrações pagas).
#     *   **Total em BRL:** 20.000 JPY * (3,42 BRL / 100 JPY) = **R$ 684**
#     *   **Justificativa:** Muitos templos e santuários têm entrada gratuita ou de baixo custo, mas museus e algumas atrações maiores cobram.
#
# 6.  **Compras e Gastos Extras (Souvenirs, Emergências):**
#     *   **Estimativa:** 30.000 - 100.000 JPY por pessoa (dependendo do interesse em compras).
#     *   **Total em BRL:** 100.000 JPY * (3,42 BRL / 100 JPY) = **R$ 3.420**
#     *   **Justificativa:** Um valor flexível para compras de moda, eletrônicos, souvenirs e um bom buffer para imprevistos.
#
# **Custo Total Estimado por Pessoa (excluindo voos):**
# *   **Em JPY:** 240.000 (hospedagem) + 55.000 (transporte) + 78.000 (alimentação) + 20.000 (atrações) + 100.000 (compras) = **493.000 JPY**
# *   **Em BRL:** R$ 8.208 + R$ 1.881 + R$ 2.668 + R$ 684 + R$ 3.420 = **R$ 16.861**
#
# **Custo Total Estimado por Pessoa (incluindo voos):**
# *   **Com voo de R$ 8.000:** R$ 8.000 + R$ 16.861 = **R$ 24.861**
# *   **Com voo de R$ 15.000:** R$ 15.000 + R$ 16.861 = **R$ 31.861**
#
# **Observação:** Estes são custos aproximados para uma viagem confortável. É possível gastar menos (optando por hostels, refeições mais baratas) ou muito mais (hotéis de luxo, restaurantes estrelados, compras extensivas).
#
# ---
#
# ### **Justificativa da Escolha do Roteiro:**
#
# 1.  **Cobertura de Interesses:** O roteiro foi desenhado para abraçar todos os interesses fornecidos:
#     *   **Cultura:** Templos (Senso-ji, Tenryu-ji, Kiyomizu-dera), Santuários (Meiji Jingu, Fushimi Inari, Kasuga Taisha), Castelos (Nijo), distritos históricos (Asakusa, Gion, Higashiyama), cerimônia do chá.
#     *   **Gastronomia:** Mercados (Nishiki), izakayas (Omoide Yokocho), sushi, ramen, tempura, kaiseki.
#     *   **Natureza:** Jardins (Shinjuku Gyoen, Arashiyama, Philosopher's Path, Hakone), folhas de outono (novembro é o pico), paisagens (Hakone, Monte Fuji).
#     *   **Modernidade:** Shibuya Crossing, arranha-céus de Shinjuku, Akihabara (tecnologia), Tokyo Skytree, Ginza.
#     *   **Compras:** Shibuya, Harajuku (moda), Akihabara (eletrônicos), Nakamise-dori, Nishiki Market (souvenirs).
#     *   **Bem-estar:** Experiência em *onsen* em Hakone com estadia em *ryokan*.
#
# 2.  **Integração dos Dados Reais:**
#     *   **Atrações:** Todos os locais específicos mencionados nos dados ("Santuário de Fushimi Inari, Pavilhão de Ouro (Kinkaku-ji), Shibuya, Harajuku, Akihabara e Asakusa") foram incorporados como pontos centrais do roteiro.
#     *   **História:** A história do Japão, desde o Paleolítico e a Era Jomon até a unificação e períodos posteriores, é contextualizada ao visitar locais como Nara (primeira capital), templos antigos e castelos.
#     *   **Câmbio:** Utilizado para fornecer estimativas de custo em BRL.
#
# 3.  **Logística Eficiente:**
#     *   **Base Dupla:** O roteiro se concentra em duas bases principais (Tóquio e Quioto), minimizando o tempo de deslocamento e maximizando o tempo de exploração.
#     *   **Trem-Bala (Shinkansen):** O uso do Shinkansen (coberto pelo JR Pass) permite viagens rápidas e confortáveis entre as cidades.
#     *   **Excursões de um dia:** Nara e Hakone são excelentes excursões de um dia a partir de Quioto e Tóquio, respectivamente, adicionando variedade sem a necessidade de mudar de hotel constantemente.
#
# 4.  **Período da Viagem (Novembro):**
#     *   Novembro é a época ideal para apreciar as **folhas de outono (koyo)**, um dos interesses principais. Locais como Shinjuku Gyoen, Arashiyama, Kiyomizu-dera e Hakone estarão em suas cores mais vibrantes, proporcionando paisagens deslumbrantes. O clima também é geralmente agradável, nem muito quente nem muito frio.
#
# Este roteiro oferece uma experiência rica e equilibrada, permitindo que você mergulhe profundamente na fascinante cultura, história, modernidade e beleza natural do Japão.
# ================================================================================
